# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## 1-Problem Statement :
#
# Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar across regions

# %% [markdown]
# ## 2 - Data description
# α == 0.05 (95% Confidence)
#
# Y == Discrete
#
# X == Discrete
#
# Since there are more than 2 variable we will perform Chi-Square test

# %% [markdown]
# ## 3 - Chi-Square Test

# %%
x = pd.read_csv("C:/Users/arvin/OneDrive/Desktop/Aditi Datascience/Aditi-ASS(DS)/HypothesisTesting _ProblemStatement/BuyerRatio.csv")

# %%
x
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %% [markdown]
# H0 == The male-female buyer rations are similar across regions
#
# H1 == The male-female buyer rations are not similar across regions

# %%
stats.chi2_contingency([x["East"], x["West"], x["North"], x["South"]])
# Out:
# (1.5959455386610577,
#  0.6603094907091882,
#  3,
#  array([[  42.76531299,  442.23468701],
#         [ 146.81287862, 1518.18712138],
#         [ 131.11756787, 1355.88243213],
#         [  72.30424052,  747.69575948]]))

# %% [markdown]
# P value of Chi-Square test == 0.66 > α

# %% [markdown]
# ### Thus HO is accepted.

# %% [markdown]
# ### The male-female buyer rations are similar across regions
